# %%
import numpy, pandas, seaborn, matplotlib

data_frame = pandas.read_csv('../data/sales_predictions.csv')

data_frame.info()

# seaborn.relplot(x='date', y='item_price', data=data_frame)

data_frame_sample = data_frame.sample(n=50)
seaborn.relplot(x='date', y='item_price', data=data_frame_sample)

relplot = seaborn.relplot(x='date', y='item_price', data=data_frame_sample)
relplot.fig.set_figwidth(20)
relplot.fig.set_figheight(6)

data_frame_sample["date"] = pandas.to_datetime(data_frame_sample["date"])

relplot = seaborn.relplot(x='date', y='item_price', data=data_frame_sample)
relplot.fig.set_figwidth(20)
relplot.fig.set_figheight(6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB
